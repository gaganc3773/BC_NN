# %%
import torch 
import torch.nn as nn
import numpy as np
import h5py
import torch.optim as optim

# Load data
file_pathtr = "train_cat.h5"
hf = h5py.File(file_pathtr, 'r')
X = np.array(hf['train_set_x'])  # Image data
Y = np.array(hf['train_set_y'])  # Labels

# Convert to PyTorch tensors
X_in = torch.tensor(X, dtype=torch.float32)
Y_in = torch.tensor(Y, dtype=torch.float32)

# Reshape and normalize input
X_norm = X_in.reshape(X_in.shape[0], -1) / 255.0  
Y_in = Y_in.view(-1, 1)  # Ensure it's column vector
Y_in = Y_in.float()  # Convert to float (needed for BCELoss)

# Define model
class Pinn(nn.Module):
    def __init__(self):
        super(Pinn, self).__init__()
        self.hidden_layers = nn.Sequential(
            nn.Linear(12288, 50), nn.ReLU(),
            nn.Linear(50, 50), nn.ReLU(),
            nn.Linear(50, 1),
            nn.Sigmoid()  # Apply sigmoid here!
        )

    def forward(self, x):
        return self.hidden_layers(x)

model = Pinn()

# Define loss and optimizer
loss_fn = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)  # Lower learning rate
# Training loop
epochs = 50
for epoch in range(epochs):
    optimizer.zero_grad()  # Reset gradients
    y_hat = model(X_norm)  # Forward pass
    cost = loss_fn(y_hat, Y_in)  # Compute loss
    cost.backward()  # Backpropagation
    optimizer.step()  # Update weights

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Loss = {cost.item():.6f}")
# Out:
# Epoch 0: Loss = 0.701163
# Epoch 10: Loss = 0.692160
# Epoch 20: Loss = 0.686135
# Epoch 30: Loss = 0.680086
# Epoch 40: Loss = 0.675405

# %%
import matplotlib.pyplot as plt

file_path="test_cat.h5"
hf=h5py.File(file_path,'r')
X_test=np.array(hf['test_set_x'])
Y_test=np.array(hf['test_set_y'])
X_test=torch.tensor(X_test,dtype=torch.float32)
Y_test=torch.tensor(Y_test,dtype=torch.float32)
X_test=X_test.reshape(X_test.shape[0],-1)/255.0
Y_test=Y_test.float().squeeze()

Y_pred = model(X_test).detach().numpy().squeeze()
cost_list=[]
no_iter=[]
epochs = 50
for epoch in range(epochs):
    optimizer.zero_grad()  # Reset gradients
    y_hat = model(X_norm)  # Forward pass
    cost = loss_fn(y_hat, Y_in)  # Compute loss
    cost_list.append(cost)
    epoch+=1
    no_iter.append(epoch)
    cost.backward()  # Backpropagation
    optimizer.step()  # Update weights

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Loss = {cost.item():.6f}")

cost_list=np.array([t.detach().numpy() for t in cost_list])

plt.figure(figsize=(15,8))
plt.plot(no_iter,cost_list)
plt.xlabel("No.of epochs")
plt.ylabel("Cost_function")
plt.title("NN model for binary classification")
plt.grid()
plt.show()
# Out:
# Epoch 10: Loss = 0.651625
# Epoch 20: Loss = 0.650908
# Epoch 30: Loss = 0.650267
# Epoch 40: Loss = 0.649690
# Epoch 50: Loss = 0.649154
